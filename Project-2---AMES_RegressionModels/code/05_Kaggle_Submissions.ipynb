# %% [markdown]
# # The model

# %% [markdown]
# the model with the highest score is Ridge Regression with Alpha of 453.33
# ![image.png](attachment:image.png)

# %% [markdown]
# *In Kaggle, ridge model is also the one with lowest MSE*

# %% [markdown]
# # Kaggle Submission

# %% [markdown]
# ![image.png](../image/kaggle_submission.png)
